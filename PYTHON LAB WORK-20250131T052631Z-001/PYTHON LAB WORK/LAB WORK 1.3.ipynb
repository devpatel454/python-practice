# %%
# 1

age = input("enter your age")

print(type(age),age)
age = int(age)
print(type(age),age)

age = float(age)
print(type(age),age)

age = bool(age)
print(type(age),age)
# Out:
# enter your age20
# <class 'str'> 20
# <class 'int'> 20
# <class 'float'> 20.0
# <class 'bool'> True

# %%
# 2

user_input = float(input("enter a number"))

print("you have entered a data type of",type(user_input))

user_input = int(user_input)
print("your data has convorted into",type(user_input))
# Out:
# enter a number24.68
# you have entered a data type of <class 'float'>
# your data has convorted into <class 'int'>

# %%
# 3 create a program

user_input = int (input("enter a boolean value"))

user_input = int(user_input)
print("your data has convert into", type(user_input),user_input)

user_input = str(user_input)
print("your data has convert into", type(user_input),user_input)
# Out:
# enter a boolean value1
# your data has convert into <class 'int'> 1
# your data has convert into <class 'str'> 1

# %%
# 4 write a datatype program


data_1 = 2804
data_2 = "hello world"
data_3 = 38.08
data_4 = True
data_5 = ["apple", "banana", "cherry"]
data_6 = (1,2,3,4,5,6)

print(type(data_1),id(data_1))
print(type(data_2),id(data_2))
print(type(data_3),id(data_3))
print(type(data_4),id(data_4))
print(type(data_5),id(data_5))
print(type(data_6),id(data_6))
# Out:
# <class 'int'> 138083029079056
# <class 'str'> 138083028118640
# <class 'float'> 138083032708880
# <class 'bool'> 9692800
# <class 'list'> 138083028445376
# <class 'tuple'> 138083027851616

# %%
# 5 create a program

a = 1
b = 1

print(id(a))
print(id(b))

b = 123
print(id(b))
# Out:
# 10750856
# 10750856
# 10754760
